# %%
import os
from PIL import Image
from PyPDF2 import PdfReader, PdfWriter
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import letter
import io

# %%
def preprocess_png(image_path, output_path):
    # Open the PNG image
    img = Image.open(image_path)
    # Convert the image to RGB mode, replacing transparency with white
    rgb_img = Image.new("RGB", img.size, (255, 255, 255))  # White background
    rgb_img.paste(img, mask=img.split()[3])  # Paste using the alpha channel as a mask
    # Save as a new file
    rgb_img.save(output_path, "PNG")

# %%
preprocess_png("tagline uc.png", "processed_logo.png")

# %%
def add_image_to_pdf(input_pdf_path, output_pdf_path, image_path):
    reader = PdfReader(input_pdf_path)
    writer = PdfWriter()
    
    img = Image.open(image_path)
    original_width, original_height = img.size
    
    print(original_width)
    print(original_height)

    for page_number in range(len(reader.pages)):
        # Calculate position for top-right corner
        page_width = float(reader.pages[page_number].mediabox.width)
        page_height = float(reader.pages[page_number].mediabox.height)
        
        # Create a PDF with just the image
        packet = io.BytesIO()
        new_page_height = page_height + 50
        can = canvas.Canvas(packet, pagesize=(page_width, new_page_height))
        
        x = 35  # 10 units of margin from the left
        y = page_height - 50 # 10 units of margin from the top

        can.drawImage(image_path, x, y, width=0.29*original_width, height=0.29*original_height)
        can.save()

        # Merge the image PDF onto the existing page
        packet.seek(0)
        image_pdf = PdfReader(packet)
        page = reader.pages[page_number]
        page.merge_page(image_pdf.pages[0])
        writer.add_page(page)
        
    with open(output_pdf_path, "wb") as output_file:
        writer.write(output_file)

# %%
def process_folder(input_folder, output_folder, image_path):
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Process all PDF files in the input folder
    for filename in os.listdir(input_folder):
        if filename.lower().endswith(".pdf"):
            input_pdf_path = os.path.join(input_folder, filename)
            output_pdf_path = os.path.join(output_folder, filename)
            
            print(f"Processing: {filename}")
            add_image_to_pdf(input_pdf_path, output_pdf_path, image_path)
            print(f"Saved to: {output_pdf_path}")

# %%
input_folder = "inp_pdf"
output_folder = "res_pdf"
image_file = "processed_logo.png"

process_folder(input_folder, output_folder, image_file)
# Out:
# Processing: ST_Adam Haidar Sang Rofi Rizq Moelyanto.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Adam Haidar Sang Rofi Rizq Moelyanto.docx.pdf
# Processing: ST_Aeron Yang.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Aeron Yang.docx.pdf
# Processing: ST_Alamanda Sofania.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Alamanda Sofania.docx.pdf
# Processing: ST_Alessandria Rensyca Hadiyanto.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Alessandria Rensyca Hadiyanto.docx.pdf
# Processing: ST_Anastasia Ellena Posuma.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Anastasia Ellena Posuma.docx.pdf
# Processing: ST_Anela Pearline.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Anela Pearline.docx.pdf
# Processing: ST_Angela Putri.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Angela Putri.docx.pdf
# Processing: ST_Anggun Meilana Herman Tinduh.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Anggun Meilana Herman Tinduh.docx.pdf
# Processing: ST_Ani Erna Sari.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Ani Erna Sari.docx.pdf
# Processing: ST_Anne Angeline Tjan.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Anne Angeline Tjan.docx.pdf
# Processing: ST_Annisa Widya Pramesti (Himika).docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Annisa Widya Pramesti (Himika).docx.pdf
# Processing: ST_Annisa Widya Pramesti (Politeknik).docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Annisa Widya Pramesti (Politeknik).docx.pdf
# Processing: ST_Aulia Sutanto.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Aulia Sutanto.docx.pdf
# Processing: ST_Beatrix Adelaide Herijanto.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Beatrix Adelaide Herijanto.docx.pdf
# Processing: ST_Benhard Lieandro.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Benhard Lieandro.docx.pdf
# Processing: ST_Berliana Lintang Alam.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Berliana Lintang Alam.docx.pdf
# Processing: ST_Berlinda Simangasing.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Berlinda Simangasing.docx.pdf
# Processing: ST_Bryan Kusumo.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Bryan Kusumo.docx.pdf
# Processing: ST_Bryan Tanaka.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Bryan Tanaka.docx.pdf
# Processing: ST_Charina Marvelly Rafa.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Charina Marvelly Rafa.docx.pdf
# Processing: ST_Cheryl Lucita Prabowo.docx (1).pdf
# 582
# 116
# Saved to: res_pdf\ST_Cheryl Lucita Prabowo.docx (1).pdf
# Processing: ST_Cheryl Lucita Prabowo.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Cheryl Lucita Prabowo.docx.pdf
# Processing: ST_Christian Tanjung Wirjoatmodjo.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Christian Tanjung Wirjoatmodjo.docx.pdf
# Processing: ST_Dennis Ariel Saputro.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Dennis Ariel Saputro.docx.pdf
# Processing: ST_Evan Kristanto.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Evan Kristanto.docx.pdf
# Processing: ST_Felita Halim.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Felita Halim.docx.pdf
# Processing: ST_Fransixco Aprilius Wijaya.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Fransixco Aprilius Wijaya.docx.pdf
# Processing: ST_James Newman (Ramadhan).docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_James Newman (Ramadhan).docx.pdf
# Processing: ST_James Newman.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_James Newman.docx.pdf
# Processing: ST_Jennifer Ivana Gunawan.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Jennifer Ivana Gunawan.docx.pdf
# Processing: ST_Jesse Cheby Halim.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Jesse Cheby Halim.docx.pdf
# Processing: ST_Jesslyn Gabrielle Hermanto.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Jesslyn Gabrielle Hermanto.docx.pdf
# Processing: ST_Jocelyn Vanessa Meidy Winarto.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Jocelyn Vanessa Meidy Winarto.docx.pdf
# Processing: ST_Joseph Eric Setiawan.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Joseph Eric Setiawan.docx.pdf
# Processing: ST_Julian Fortune Setiawan.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Julian Fortune Setiawan.docx.pdf
# Processing: ST_Kevin Rich Poajaya.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Kevin Rich Poajaya.docx.pdf
# Processing: ST_Kezia Hannah Mamarimbing.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Kezia Hannah Mamarimbing.docx.pdf
# Processing: ST_Kezia Jasmine Winata.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Kezia Jasmine Winata.docx.pdf
# Processing: ST_Leroy Setiadarma.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Leroy Setiadarma.docx.pdf
# Processing: ST_Luh Putu Susila Adnyani.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Luh Putu Susila Adnyani.docx.pdf
# Processing: ST_Manna Glory Hangoluan Hutabarat.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Manna Glory Hangoluan Hutabarat.docx.pdf
# Processing: ST_Marzenda Saila.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Marzenda Saila.docx.pdf
# Processing: ST_Melati Resda Ceasaria.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Melati Resda Ceasaria.docx.pdf
# Processing: ST_Nabil Arhamniazi.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Nabil Arhamniazi.docx.pdf
# Processing: ST_Nashwa Farenza Anataya.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Nashwa Farenza Anataya.docx.pdf
# Processing: ST_Nevita Boedyono Subagio.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Nevita Boedyono Subagio.docx.pdf
# Processing: ST_Nicklaus Stanley.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Nicklaus Stanley.docx.pdf
# Processing: ST_Pradibta Bintang Maulana.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Pradibta Bintang Maulana.docx.pdf
# Processing: ST_Raff Melvern Surya Gunawan.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Raff Melvern Surya Gunawan.docx.pdf
# Processing: ST_Robert Han.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Robert Han.docx.pdf
# Processing: ST_Ryeiyang Valerian Donvikho.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Ryeiyang Valerian Donvikho.docx.pdf
# Processing: ST_Rytney Electra Sheyoputri.docx (1).pdf
# 582
# 116
# Saved to: res_pdf\ST_Rytney Electra Sheyoputri.docx (1).pdf
# Processing: ST_Rytney Electra Sheyoputri.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Rytney Electra Sheyoputri.docx.pdf
# Processing: ST_Steven Adi Santoso (Widya Mandala).docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Steven Adi Santoso (Widya Mandala).docx.pdf
# Processing: ST_Steven Adi Santoso.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Steven Adi Santoso.docx.pdf
# Processing: ST_Steven Cahyono.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Steven Cahyono.docx.pdf
# Processing: ST_Valencia Aquilina.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Valencia Aquilina.docx.pdf
# Processing: ST_Valentyno Marcel Gunawan.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Valentyno Marcel Gunawan.docx.pdf
# Processing: ST_Videlia Gracia Salim.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Videlia Gracia Salim.docx.pdf
# Processing: ST_William Nata.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_William Nata.docx.pdf
# Processing: ST_Yosua Pirono.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Yosua Pirono.docx.pdf
# Processing: ST_Yusuf Haryanto Wijaya.docx.pdf
# 582
# 116
# Saved to: res_pdf\ST_Yusuf Haryanto Wijaya.docx.pdf
