# %%
import pandas as pd

# %%
df_submission= pd.read_excel("Kompetisi Januari 2024-Oktober 2024.xlsx", sheet_name="Worksheet")

# %%
df_scholarship= pd.read_excel("Kompetisi Januari 2024-Oktober 2024.xlsx", sheet_name="Data Beasiswa All")

# %%
df_scholarship
# Out:
#                               Nama           NIM  Angkatan  \
# 0     Zefanya Oktaviana Indrasanti  7.060220e+11      20.0
# 1                    Ellen Sutanto  1.060420e+11      20.0
# 2        KIRANA RATU SEKAR KEDATON  5.060120e+11      20.0
# 3                  Fikri Alvirhino  5.060120e+11      20.0
# 4           Nabila Aurelia Syahrin  1.060120e+11      20.0
# ...                            ...           ...       ...
# 1024                  Nelson Davio  1.060124e+11      24.0
# 1025       Felix Cristian Soenjaya  5.060124e+11      24.0
# 1026           Akhnan Iban Fahrezi  7.060224e+11      24.0
# 1027              Bimo Putra Imawi  1.060124e+11      24.0
# 1028                           NaN           NaN       NaN
#
#                    Program Studi Status Beasiswa  \
# 0             Information System       Non-Aktif
# 1                     Accounting       Non-Aktif
# 2          Communication Science       Non-Aktif
# 3          Communication Science       Non-Aktif
# ...
