# %%
from docx import Document
from docx.shared import Pt
import pandas as pd
from datetime import datetime
import os
import re
import locale

# %%
excel_path = "HARDIKNAS.xlsx"
data = pd.read_excel(excel_path, sheet_name = "Worksheet", dtype={"NIS": str})

# %%
template_path = "template.docx"

# %%
indv_output_folder = "output_letters/hardiknas"
if not os.path.exists(indv_output_folder):
    os.makedirs(indv_output_folder)

# %%
def format_dates(row):
    locale.setlocale(locale.LC_TIME, "id_ID.UTF-8")
    
    start_date = pd.to_datetime(row['Start Date'])
    end_date = pd.to_datetime(row['End Date'])
    
    # Format day and date (e.g., "Selasa - Kamis/26 - 28 April 2024")
    start_day = start_date.strftime("%A")  # Day of the week
    start_formatted = start_date.strftime("%d %B %Y")  # Date in "26 April 2024" format
    end_day = end_date.strftime("%A")
    end_formatted = end_date.strftime("%d %B %Y")
    
    return f"{start_day} - {end_day}/{start_formatted} - {end_formatted}"

# %%
def format_signatures(row):
    locale.setlocale(locale.LC_TIME, "id_ID.UTF-8")
    start_date = pd.to_datetime(row['Start Date'])
    
    # Format day and date (e.g., "Selasa - Kamis/26 - 28 April 2024")
    start_formatted = start_date.strftime("%d %B %Y")  # Date in "26 April 2024" format
    
    return f"Surabaya, {start_formatted}"

# %%
def replace_surabaya_paragraph(doc, row):
    """Replace 'Surabaya, <date>' in paragraphs and output changes."""
    signature_date = format_signatures(row)  # Format the new date
    pattern = r"Surabaya,\s+\d{1,2}\s+\w+\s+\d{4}"  # Regex pattern for 'Surabaya, <date>'
    
    for paragraph in doc.paragraphs:
        if re.search(pattern, paragraph.text):
            old_text = paragraph.text  # Save the original text for logging
            paragraph.text = re.sub(pattern, signature_date, paragraph.text)  # Replace text
            print(f"Changed: '{old_text}' to '{paragraph.text}'")  # Output the change

# %%
def sanitize_filename(filename):
    return "".join(c for c in filename if c.isalnum() or c in " _-()").strip()

# %%
doc = Document(template_path)

# %%
print("\nTables:")
for table_index, table in enumerate(doc.tables):
    print(f"Table {table_index + 1}:")
    for row_index, row in enumerate(table.rows):
        row_data = [repr(cell.text) for cell in row.cells]
        print(f"  Row {row_index + 1}: {row_data}")
# Out:
# Tables:
# Table 1:
#   Row 1: ["''", "''"]
# Table 2:
#   Row 1: ["'No'", "'Nama'", "'NIM/NIK'", "'Departemen/Prodi'"]
#   Row 2: ["'1'", "'Rean Mitasari'", "'0731108905'", "'Dosen Pendamping'"]
#   Row 3: ["'2'", "'Jocelyn Vanessa Meidy Winarto'", "'0406012110026'", "'HTB'"]
# Table 3:
#   Row 1: ["'Tugas'", "':'", "'Mengikuti Lomba CAK NING UC 2024'"]
#   Row 2: ["'Hari/Tanggal'", "':     '", "'Rabu - Kamis/27 Maret - 18 April 2024'"]
#   Row 3: ["'Tempat\\n\\n'", "':\\n\\n'", "'Universitas Ciputra Surabaya'"]

# %%
for index, row in data.iterrows():
    table = doc.tables[1]
    
    for _ in range(len(table.rows) - 1):
        table._tbl.remove(table.rows[1]._tr)
    
    lecturer_name = row['Nama Dosen PA']
    lecturer_nidn = row['NIDN Dosen PA']

    # Add lecturer information
    lecturer_row = table.add_row().cells
    lecturer_row[0].text = "1"  # No
    lecturer_row[1].text = lecturer_name  # Nama
    lecturer_row[2].text = str(lecturer_nidn)  # NIM/NIK
    lecturer_row[3].text = "Dosen Pendamping"  # Departemen/Prodi
    
    student_name = row['Name']
    student_nis = row['NIS']
    student_department = row['Major']
        
    # Add student information
    student_row = table.add_row().cells
    student_row[0].text = "2"  # N
    student_row[1].text = student_name  # Nama
    student_row[2].text = str(student_nis)  # NIM/NIK
    student_row[3].text = student_department  # Departemen/Prodi
    
    info_table = doc.tables[2]

    if len(info_table.rows) > 0:
        tugas_cell = info_table.rows[0].cells[2]
        tugas_cell.text = f"Mengikuti {row['Activity']}"

    if len(info_table.rows) > 1:
        haritanggal_cell = info_table.rows[1].cells[2]
        haritanggal_cell.text = format_dates(row)
    
    replace_surabaya_paragraph(doc, row)
    
    for paragraph in doc.paragraphs:
        if "No. :" in paragraph.text:  # Match paragraphs with "No. :"
            old_text = paragraph.text
            # Use a regex to replace the entire identifier after "No. :"
            new_text = re.sub(r"No\. :\s*[\w/-]+", f"No. : {row['Nomor ST']}", old_text)
            paragraph.text = new_text
            print(row['Nomor ST'])
            print(f"Updated 'Nomor ST' from: '{old_text}' to: '{paragraph.text}'")


    # Save the updated document
    sanitized_name = sanitize_filename(row['Name'])
    sanitized_activity = sanitize_filename(row['Activity'])
    indv_output_path = f"{indv_output_folder}/ST_{sanitized_name} ({sanitized_activity}).docx"
    
    print(f"Saving Word document to: {indv_output_path}")  
    
    doc.save(indv_output_path)
    print(f"Word document saved to {indv_output_path}")
# Out:
# Changed: 'Surabaya, 27 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00023H/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_JONATHAN XAVIER KUSUMA (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_JONATHAN XAVIER KUSUMA (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_JOCELYN WUISAN (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_JOCELYN WUISAN (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_IVY JOCELYN HARYANTO (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_IVY JOCELYN HARYANTO (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_JOVAN LOUIS LEMUEL (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_JOVAN LOUIS LEMUEL (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_CHARLIE ALVIN SUYANTO (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_CHARLIE ALVIN SUYANTO (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_NADHISA DEVARAINY GLADYS IRAWAN (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_NADHISA DEVARAINY GLADYS IRAWAN (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_Mochammad Muflih (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_Mochammad Muflih (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_Feishya Mitzvella (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_Feishya Mitzvella (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_Jenson tai (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_Jenson tai (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_STEFANY ALICIA TJANDRA (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_STEFANY ALICIA TJANDRA (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_ABROR NUJHA (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_ABROR NUJHA (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_WANDA TIARA CRISTIVANY (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_WANDA TIARA CRISTIVANY (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_KHAIZURAN ASYRAAF RABBANI (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_KHAIZURAN ASYRAAF RABBANI (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_ALLODIA ASTRIED BRENNADIVA (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_ALLODIA ASTRIED BRENNADIVA (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_SOFI HAMDANY (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_SOFI HAMDANY (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_DAVE GIDEON TANJUNG WIRJOATMODJO (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_DAVE GIDEON TANJUNG WIRJOATMODJO (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_Calista aurora widjaja (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_Calista aurora widjaja (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_KENNAN ALQISTHI MARTHARAHMANDANI (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_KENNAN ALQISTHI MARTHARAHMANDANI (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_BRYAN RAFFERTY MUDITA HUANG (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_BRYAN RAFFERTY MUDITA HUANG (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_Ella Rubiana Habibah (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_Ella Rubiana Habibah (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_CARIVAN STEFEN SUTANTO (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_CARIVAN STEFEN SUTANTO (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_FLORENCE ADOLYA SOPUTRA (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_FLORENCE ADOLYA SOPUTRA (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_CALISTA LUKITO (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_CALISTA LUKITO (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_SAMUEL HALIM (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_SAMUEL HALIM (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_SHANNEN PURNOMO HALIM (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_SHANNEN PURNOMO HALIM (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_EDITH NATANIA (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_EDITH NATANIA (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_DIAZ ZAHRA YUMESA (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_DIAZ ZAHRA YUMESA (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_ERIN NATASHA TOBING (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_ERIN NATASHA TOBING (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_Dave Valentino Irawan (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_Dave Valentino Irawan (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_RAYDEN LIMADINATA (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_RAYDEN LIMADINATA (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_BRYAN RAYON LAY (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_BRYAN RAYON LAY (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_Shannon Chrestella Valencia (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_Shannon Chrestella Valencia (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_NICHOLAS MARCELL WIBISONO (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_NICHOLAS MARCELL WIBISONO (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_YEMIMA AUSTIN MATIANDANO SEHIMPUN (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_YEMIMA AUSTIN MATIANDANO SEHIMPUN (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_Ongki Putri Ayunisia (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_Ongki Putri Ayunisia (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_TIFFANY GRACE SIAMENA (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_TIFFANY GRACE SIAMENA (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_Farras Nur Shaalihaati (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_Farras Nur Shaalihaati (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_FIONNA MELIORA JIANG (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_FIONNA MELIORA JIANG (HARDIKNAS Public Speaking Competition).docx
# Changed: 'Surabaya, 18 Maret 2024' to 'Surabaya, 18 Maret 2024'
# 00011O/UC-BMA/ST/III/2024
# Updated 'Nomor ST' from: 'No. : 00011O/UC-BMA/ST/III/2024
# ' to: 'No. : 00011O/UC-BMA/ST/III/2024
# '
# Saving Word document to: output_letters/hardiknas/ST_Nathania devina setyawan (HARDIKNAS Public Speaking Competition).docx
# Word document saved to output_letters/hardiknas/ST_Nathania devina setyawan (HARDIKNAS Public Speaking Competition).docx
